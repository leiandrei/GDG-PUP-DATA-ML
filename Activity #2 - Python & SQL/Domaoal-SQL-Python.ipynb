# %% [markdown]
# # **Querying Excellence: A Data-Driven Performance Review**

# %% [markdown]
# # **Scenario**
#
# ---
#
# The College of Computer and Information Sciences (**CCIS**) of Polytechnic University of the Philippines (**PUP**) is conducting an internal performance review for the 1st Quarter of 2024.
# The dean has requested a detailed data-driven analysis of student assessment results across all year levels and major CCIS subjects.
#
# As part of this study session, you will take the role of a Data Analyst for PUP CCIS.
#
# Your responsibility is to:
#
#
#
# *   Investigate academic performance patterns
# *   Identify struggling subjects or year levels
# *   Evaluate teacher effectiveness
# *   Present actionable insights based on SQL results
#
#
# You will work with a dataset compiled from various CCIS instructors to support curriculum planning, academic interventions, and resource allocation.

# %% [markdown]
# # The expected outputs:
# ![Screenshot 2025-12-07 155112.png](data:image/png;base64,...)![Screenshot 2025-12-07 155127.png](data:image/png;base64,...)
# ![Screenshot 2025-12-07 155242.png](data:image/png;base64,...)
# ![Screenshot 2025-12-07 155256.png](data:image/png;base64,...)
# ![Screenshot 2025-12-07 155308.png](data:image/png;base64,...)
# ![Screenshot 2025-12-07 155345.png](data:image/png;base64,...)
# ![Screenshot 2025-12-07 155358.png](data:image/png;base64,...)
# ![Screenshot 2025-12-07 155416.png](data:image/png;base64,...)

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import sqlite3

#import pandas and sqlite3

# %% [markdown]
# # Dataset for your SQL analysis
#
# This is your provided and default dataset. Kindly run this code to access the dataset :>>

# %%
data = {
    'record_id': range(1, 21),
    'date': [
        '2024-01-10', '2024-01-12', '2024-01-15', '2024-02-01', '2024-02-03',
        '2024-02-15', '2024-03-01', '2024-03-02', '2024-03-05', '2024-03-10',
        '2024-01-20', '2024-01-25', '2024-02-18', '2024-02-22', '2024-03-12',
        '2024-03-15', '2024-01-08', '2024-02-10', '2024-03-20', '2024-03-25'
    ],
    'student_name': [
        'Alice', 'Bob', 'Charlie', 'Diana', 'Ethan',
        'Fiona', 'George', 'Hannah', 'Ivan', 'Julia',
        'Kevin', 'Luna', 'Mason', 'Nora', 'Owen',
        'Penelope', 'Quinn', 'Riley', 'Sophia', 'Tom'
    ],
    'year_level': [
        1, 2, 1, 3, 4,
        2, 1, 3, 2, 4,
        1, 3, 4, 2, 3,
        1, 2, 4, 3, 1
    ],
    'subject': [
        'Programming', 'OOP', 'Multimedia', 'Data Structures and Algorithm', 'Programming',
        'OOP', 'Multimedia', 'Programming', 'Data Structures and Algorithm', 'OOP',
        'Multimedia', 'Programming', 'Data Structures and Algorithm', 'OOP', 'Multimedia',
        'Programming', 'OOP', 'Data Structures and Algorithm', 'Programming', 'Multimedia'
    ],
    'score': [
        88, 92, 75, 85, 95,
        78, 90, 82, 70, 88,
        94, 76, 83, 91, 67,
        89, 72, 80, 98, 73
    ],
    'professor': [
        'Mr. Batumbakal', 'Ms. Amihan', 'Mr. Wazowski', 'Ms. Nakita', 'Mr. Batumbakal',
        'Ms. Amihan', 'Mr. Wazowski', 'Ms. Nakita', 'Mr. Batumbakal', 'Ms. Amihan',
        'Mr. Wazowski', 'Ms. Nakita', 'Mr. Batumbakal', 'Ms. Amihan', 'Mr. Wazowski',
        'Ms. Nakita', 'Mr. Batumbakal', 'Ms. Amihan', 'Mr. Wazowski', 'Ms. Nakita'
    ],
    'activity_type': [
        'Midterm', 'Quiz', 'Project', 'Final', 'Project',
        'Midterm', 'Quiz', 'Final', 'Midterm', 'Project',
        'Final', 'Quiz', 'Project', 'Midterm', 'Quiz',
        'Final', 'Project', 'Midterm', 'Quiz', 'Project'
    ]
}

df = pd.DataFrame(data)
df
# Out:
#     record_id        date student_name  year_level  \
# 0           1  2024-01-10        Alice           1
# 1           2  2024-01-12          Bob           2
# 2           3  2024-01-15      Charlie           1
# 3           4  2024-02-01        Diana           3
# 4           5  2024-02-03        Ethan           4
# 5           6  2024-02-15        Fiona           2
# 6           7  2024-03-01       George           1
# 7           8  2024-03-02       Hannah           3
# 8           9  2024-03-05         Ivan           2
# 9          10  2024-03-10        Julia           4
# 10         11  2024-01-20        Kevin           1
# 11         12  2024-01-25         Luna           3
# 12         13  2024-02-18        Mason           4
# 13         14  2024-02-22         Nora           2
# 14         15  2024-03-12         Owen           3
# 15         16  2024-03-15     Penelope           1
# 16         17  2024-01-08        Quinn           2
# ...

# %% [markdown]
# # Connect to an in-memory SQLite database

# %%
#input code here
try:
    conn = sqlite3

# %% [markdown]
# # Write the dataframe to SQL

# %%
#input code here

# %% [markdown]
# # Preview your raw Data

# %%
#input code here

# %%
#input code here
# define your run_query function

# %% [markdown]
# # WHERE and LIKE
# **The Assistant Dean for Academic Affairs requests:**
#
# Show all Year 1 and Year 2 CCIS students who scored BETWEEN 85 and 100 in any subject where the activity_type contains the word 'midterm' (case-insensitive), during Q1 2024.

# %%
#input code here

# %% [markdown]
# # GROUP BY
# **The Program Chair needs a quick overview:**
#
# For each CCIS subject, provide the number of assessments, total points earned, and average score.

# %%
#input code here

# %% [markdown]
# # HAVING
# **The Dean of CCIS wants to identify strong areas:**
#
# Return only the subjects with an average score ABOVE 80 during Q1 2024.

# %%
#input code here

# %% [markdown]
# # CASE WHEN
#
# **The Curriculum Development Committee wants score segmentation:**
#
# Create the following performance tiers:
#
#
# *   Excellent = score ≥ 90
# *   Proficient = score 75–89
# *   Needs Improvement = score < 75
#
# Return:
#
# *   student_name
# *   subject
# *   score
# *   performance_tier
#
# Order results by highest score first.

# %%
#input code here

# %% [markdown]
# # SUB-QUERY
# For the Faculty Evaluation Report, you must determine:
#
# Which professors have an average student score higher than the overall subject average they teach?

# %%
#input code here

# %% [markdown]
# # Data Visualization
# **For the CCIS Performance Dashboard, you must visualize a bar chart that shows:**
#
# How the average student score differs across the four major CCIS subjects during Q1 2024.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# import matplotlib and seaborn

# %%
#input code here
# define query,
# assign query to a variable

# %%
#input code here
# make your own chart here

# %% [markdown]
# # That’s a wrap! 🎉
#
# Today you learned how to filter data with precision, summarize information through aggregation, distinguish WHERE vs. HAVING, and use CTEs to structure complex queries. You also explored how SQL results flow directly into Python for visualization.
#
# Keep experimenting, keep exploring, and continue building your analytical skills 😼😼
# ![G6Iwwuja4AAl4Dt.jpg](data:image/jpeg;base64,...)
